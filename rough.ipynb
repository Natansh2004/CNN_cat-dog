# %%
import cv2
from PIL import Image

# %%
image_path = r'C:\Users\Dell\OneDrive\Desktop\Machine_Learning\CNN\Data\images\dogs\dog.4025.jpg'
img = Image.open(image_path)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x374>

# %%
img_arr = cv2.imread(image_path)
img_arr
# Out:
# array([[[100, 107,  62],
#         [ 63,  70,  25],
#         [ 66,  73,  30],
#         ...,
#         [ 54,  41,  15],
#         [ 69,  56,  30],
#         [ 69,  56,  30]],
#
#        [[ 60,  64,  22],
#         [ 74,  81,  38],
#         [ 97, 101,  59],
#         ...,
#         [100,  87,  61],
#         [120, 107,  81],
#         [128, 115,  89]],
#
#        [[ 93,  94,  54],
#         [105, 109,  68],
#         [130, 131,  91],
#         ...,
#         [ 54,  41,  15],
#         [ 69,  56,  30],
#         [ 79,  66,  40]],
#
#        ...,
#
#        [[ 65,  69,  27],
#         [ 95, 102,  59],
#         [106, 112,  71],
#         ...,
#         [ 25,  22,   1],
#         [ 18,  15,   0],
#         [ 31,  28,   7]],
#
#        [[ 71,  75,  33],
#         [ 99, 106,  63],
#         [ 86,  92,  51],
#         ...,
#         [ 27,  24,   3],
#         [ 31,  28,   7],
#         [ 34,  31,  10]],
#
#        [[ 38,  42,   0],
#         [ 78,  85,  42],
#         [ 68,  74,  33],
# ...

# %%
type(img_arr)
# Out:
# numpy.ndarray

# %%
resized_img = cv2.resize(img_arr,(150,150))
resized_img
# Out:
# array([[[ 74,  81,  37],
#         [ 89,  91,  53],
#         [ 73,  68,  37],
#         ...,
#         [ 91,  68,  44],
#         [ 71,  49,  25],
#         [104,  91,  65]],
#
#        [[ 92,  90,  53],
#         [ 93,  87,  54],
#         [ 78,  69,  39],
#         ...,
#         [ 76,  58,  38],
#         [ 69,  50,  31],
#         [ 46,  33,   7]],
#
#        [[ 51,  39,  10],
#         [100,  87,  58],
#         [101,  86,  56],
#         ...,
#         [ 67,  52,  36],
#         [ 82,  67,  49],
#         [ 83,  68,  42]],
#
#        ...,
#
#        [[ 51,  51,  17],
#         [ 37,  38,   6],
#         [ 61,  63,  30],
#         ...,
#         [ 36,  32,   5],
#         [ 89,  85,  63],
#         [ 58,  52,  27]],
#
#        [[ 61,  68,  26],
#         [ 66,  75,  38],
#         [ 37,  48,  15],
#         ...,
#         [ 38,  37,   8],
#         [ 83,  80,  59],
#         [ 43,  40,  19]],
#
#        [[ 92,  98,  56],
#         [ 60,  69,  32],
#         [ 83,  94,  60],
# ...

# %%
type(resized_img)
# Out:
# numpy.ndarray

# %%
print('Hello',\
      'Hi')
# Out:
# Hello Hi

# %%
list((10,20,50,2.4,'abc',
     True,45.2))
# Out:
# [10, 20, 50, 2.4, 'abc', True, 45.2]
